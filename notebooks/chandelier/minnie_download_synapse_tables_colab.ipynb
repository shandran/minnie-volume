# %%
# !pip install -q caveclient
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.5 MB/s eta 0:00:00

# %%
from caveclient import CAVEclient
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_path = '/content/drive/MyDrive/minnie65/synapse_tables/'

# %%
from google.colab import userdata

os.environ["CAVECLIENT_TOKEN"] = userdata.get('CAVECLIENT_TOKEN')
caveclient_key = os.getenv('CAVECLIENT_TOKEN')
#print(caveclient_key)

# %%
# caveclient_key

# %%
client = CAVEclient("minnie65_public", auth_token=caveclient_key)

# %%
client.materialize.get_versions()
# Out:
# [1078, 117, 661, 343, 1181, 795, 943]

# %%
for version in client.materialize.get_versions():
    print(f"Version {version}: {client.materialize.get_timestamp(version)}")
# Out:
# Version 1078: 2024-06-05 10:10:01.203215+00:00
# Version 117: 2021-06-11 08:10:00.215114+00:00
# Version 661: 2023-04-06 20:17:09.199182+00:00
# Version 343: 2022-02-24 08:10:00.184668+00:00
# Version 1181: 2024-09-16 10:10:01.121167+00:00
# Version 795: 2023-08-23 08:10:01.404268+00:00
# Version 943: 2024-01-22 08:10:01.497934+00:00

# %%
client.version=1181

# %%
my_root_id = 864691135397985569 #864691135105583693 #864691136175611654 #864691136143665204 #864691135585333116 #864691135491223143 #864691135857084462 #864691135848859998 #864691135992809921 #864691135989325056 #864691136105678041 #864691136042196822 #864691135763235638 #864691136275359757 #864691136195064278 #864691136144684340 #864691135645080047 #864691135527145819 #864691135013881590 #864691136380268245 #864691135349628119 #864691136228447569 #864691135135829529 #864691135135382809 #864691136090904756 #864691135135829529 #864691135776009133 #864691135587226354 #864691136237449532 #864691135866387734 #864691135675330756 #864691136781187182

# %%
# Pull output synapses for my_root_id
syn_df_pre = client.materialize.synapse_query(pre_ids=my_root_id)
print(f"Total number of output synapses for {my_root_id}: {len(syn_df_pre)}")
syn_df_pre.head()
# Out:
# Total number of output synapses for 864691135397985569: 301
#           id                          created  superceded_id valid   size  \
# 0  404931405 2020-11-04 06:48:59.326085+00:00            NaN     t   6100
# 1  382604970 2020-11-04 06:48:59.510128+00:00            NaN     t   1636
# 2  403854339 2020-11-04 06:49:11.545614+00:00            NaN     t   2084
# 3  385002847 2020-11-04 06:49:11.545614+00:00            NaN     t   2468
# 4  427032923 2020-11-04 06:53:24.912290+00:00            NaN     t  12712
#
#    pre_pt_supervoxel_id      pre_pt_root_id  post_pt_supervoxel_id  \
# 0    109432675198581331  864691135397985569     109432675198577279
# 1    107528732973313968  864691135397985569     107528732973337107
# 2    109499607767656143  864691135397985569     109499607767655080
# 3    107672493984493151  864691135397985569     107672493984497832
# 4    111333249632055074  864691135397985569     111333318351529892
#
# ...

# %%
# Save the DataFrame as a CSV file
syn_df_pre.to_csv(f"{drive_path}/{my_root_id}_syn_df_pre.csv", index=False)

# %%
# pull input synapses for my_root_id
syn_df_post = client.materialize.synapse_query(post_ids=my_root_id)
print(f"Total number of input synapses for {my_root_id}: {len(syn_df_post)}")
syn_df_post.head()
# Out:
# Total number of input synapses for 864691135397985569: 4555
#           id                          created  superceded_id valid   size  \
# 0  405121119 2020-11-04 06:48:59.036865+00:00            NaN     t  13496
# 1  416857574 2020-11-04 06:48:59.403833+00:00            NaN     t   8684
# 2  416432843 2020-11-04 06:48:59.326085+00:00            NaN     t   5228
# 3  389474611 2020-11-04 06:49:11.886757+00:00            NaN     t   2164
# 4  403289856 2020-11-04 06:49:11.886757+00:00            NaN     t   1276
#
#    pre_pt_supervoxel_id      pre_pt_root_id  post_pt_supervoxel_id  \
# 0    109356671188892750  864691135706697056     109356671188882080
# 1    110552458870595995  864691136524105981     110552458870594810
# 2    110696632198451368  864691134990697805     110696632198451550
# 3    108090239951826046  864691135467990980     108090239951828332
# 4    109288639040671287  864691135463229380     109288707760140610
#
# ...

# %%
# Save the DataFrame as a CSV file
syn_df_post.to_csv(f"{drive_path}/{my_root_id}_syn_df_post.csv", index=False)
