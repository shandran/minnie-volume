# %%
# !pip install -q caveclient
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.3 MB/s eta 0:00:00

# %%
#!pip show caveclient

# %%
# !pip install -q nglui
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.8/820.8 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 35.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 63.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 11.6 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.30.0 which is incompatible.
# ...

# %%
#!pip show nglui

# %%
import caveclient
from nglui import statebuilder
import pandas as pd
import numpy as np
import os

# %%
from google.colab import userdata

os.environ["CAVECLIENT_TOKEN"] = userdata.get('CAVECLIENT_TOKEN')
caveclient_key = os.getenv('CAVECLIENT_TOKEN')
#print(caveclient_key)

# %%
from caveclient import CAVEclient
client = CAVEclient('minnie65_public', auth_token=caveclient_key)

# %%
#client.materialize.get_versions()

# %%
client.version=1181

# %%
# Show output synapses of index 0 in query with additional output ids

table_name = 'nucleus_ref_neuron_svm'

root_id_query = [864691135349628119, 864691135616427625, 864691136228111441, 864691135338802662, 864691136663195614, 864691134918592778]
#[864691135349628119, 864691136228111441]

statebuilder.helpers.make_neuron_neuroglancer_link(
    client,
    root_id_query,
    show_inputs=False,
    show_outputs=True,
    target_site='spelunker'
)
# Out:
# <a href="https://spelunker.cave-explorer.org/#!middleauth+https://global.daf-apis.com/nglstate/api/v1/6497003140808704">Neuroglancer Link</a>

# %%
# Load a list of root ids with no synapse visualization

table_name = 'nucleus_ref_neuron_svm'

root_id_query = [864691135734347924, 864691135397985569, 864691135654067394, 864691135163372333, 864691135865689052, 864691135715192212, 864691136903581874, 864691136389313399, 864691135865707228, 864691135947158308, 864691136134434699, 864691135715440922, 864691135544614952, 864691135082003959, 864691136137198461, 864691135257423535, 864691136451879423, 864691135841410787, 864691135761994038, 864691136123732518, 864691135940893606, 864691136740460636, 864691135685089463, 864691135816677711, 864691136911864561, 864691134940771939, 864691135382942682, 864691136084077676, 864691135584827768, 864691135502610242, 864691135491137383, 864691135815478863, 864691135527337307, 864691135693705407, 864691135508703241, 864691135776604000, 864691135945453860, 864691135952477731, 864691137020671342]

#[864691135349628119, 864691135616427625, 864691136228111441, 864691135338802662, 864691136663195614, 864691134918592778]
#[864691135349628119, 864691136228111441]

statebuilder.helpers.make_neuron_neuroglancer_link(
    client,
    root_id_query,
    show_inputs=False,
    show_outputs=False,
    target_site='spelunker'
)
# Out:
# <a href="https://spelunker.cave-explorer.org/#!middleauth+https://global.daf-apis.com/nglstate/api/v1/4619448188141568">Neuroglancer Link</a>

# %%
# sort by value counts
# materialize an ng link of output ids from a query id of interest

table_name = 'nucleus_ref_neuron_svm'

my_root_id = [864691135397985569] #[864691135938797316] #[864691135501971037] #[864691135469090898] #[864691135345174431] #[864691136483908140] #[864691135105583693] #[864691136768713582] #[864691135947610977] #[864691135864981118] #[864691136924219620] #[864691135644589295]
size = 50

# Pull output synapses for my_root_id
syn_df_pre = client.materialize.synapse_query(pre_ids=my_root_id)
#print(f"Total number of output synapses for {my_root_id}: {len(syn_df_pre)}")
#syn_df_pre.head()

top_counts = syn_df_pre.post_pt_root_id.value_counts()
root_id_output_list = top_counts.index.tolist()[:size]

#root_id_output_list = syn_df_pre.post_pt_root_id.unique().tolist()[:size]

root_id_query = my_root_id + root_id_output_list

statebuilder.helpers.make_neuron_neuroglancer_link(
    client,
    root_id_query,
    show_inputs=False,
    show_outputs=False,
    target_site='spelunker'
)
# Out:
# <a href="https://spelunker.cave-explorer.org/#!middleauth+https://global.daf-apis.com/nglstate/api/v1/5611434705682432">Neuroglancer Link</a>

# %%
top_counts.head(size)
# Out:
# post_pt_root_id
# 864691136389425783    6
# 864691135590803467    5
# 864691135876855379    5
# 864691135479068358    5
# 864691135718708273    5
# 864691136617703131    4
# 864691136274045374    4
# 864691134965433631    4
# 864691135210965952    4
# 864691135446178450    4
# 864691136311785021    4
# 864691135100839712    4
# 864691136812291955    4
# 864691135684979127    3
# 864691136952195039    3
# 864691135754711245    3
# 864691135639768379    3
# 864691135852138183    3
# 864691135992285633    3
# 864691136106306777    3
# 864691135940597926    3
# 864691135926607118    3
# 864691135355358927    3
# 864691136452081151    3
# 864691135975509615    3
# 864691135619035535    3
# 864691135355607247    3
# 864691135447698772    3
# 864691136273494206    3
# 864691135995819178    3
# 864691135382949338    3
# 864691136577498388    2
# 864691135156007524    2
# 864691135590845963    2
# 864691135582685938    2
# 864691135734347924    2
# 864691135859486056    2
# ...

# %%
# # this one does not sort by most contacts first
# # materialize an ng link of output ids from a query id of interest

# table_name = 'nucleus_ref_neuron_svm'

# my_root_id = [864691135864981118] #[864691136924219620] #[864691135644589295]
# size = 50

# # Pull output synapses for my_root_id
# syn_df_pre = client.materialize.synapse_query(pre_ids=my_root_id)
# #print(f"Total number of output synapses for {my_root_id}: {len(syn_df_pre)}")
# #syn_df_pre.head()

# root_id_output_list = syn_df_pre.post_pt_root_id.unique().tolist()[:size]

# root_id_query = my_root_id + root_id_output_list

# statebuilder.helpers.make_neuron_neuroglancer_link(
#     client,
#     root_id_query,
#     show_inputs=False,
#     show_outputs=False,
#     target_site='spelunker'
# )
