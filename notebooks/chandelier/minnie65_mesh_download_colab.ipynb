# %% [markdown]
# Thank you Bethanny Danskin and Forrest Collman from the Allen Institute for providing example code notebooks and for coding assistance.

# %%
# Install caveclient
# %pip install -q caveclient
# %pip install -q meshparty

import numpy as np
from datetime import datetime

from caveclient import CAVEclient
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.3/94.3 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.7/213.7 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 704.8/704.8 kB 35.1 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata

os.environ["CAVECLIENT_TOKEN"] = userdata.get('CAVECLIENT_TOKEN')
user_token = os.getenv('CAVECLIENT_TOKEN')
#print(user_token)

# %%
# @title Initialize CAVE
# @markdown Requires your unique user token. Input token if you have one

client = CAVEclient()
#user_token = '' # @param {type: "string"}

try:
  client.auth.save_token(token=user_token, overwrite=True)
  # Initialize a client for the production datastack.
  client = CAVEclient(datastack_name='minnie65_public')

  cg = client.chunkedgraph
  print('Client initiation successful!')
except:
  print('Oops! Token does not work')
  print('Go to: https://global.daf-apis.com/auth/api/v1/user/token to view a list of your existing tokens')
  print('If you have never made a token before: \n  1) go here: https://minnie.microns-daf.com/materialize/views/datastack/minnie65_public to accept terms of service \n  2) then go here https://global.daf-apis.com/auth/api/v1/create_token to create a new token.')

# @markdown ---
# Out:
# Client initiation successful!

# %%
from cloudvolume import CloudVolume
from meshparty import trimesh_io

# Define the dynamic segmentation
seg_source = 'graphene://https://minnie.microns-daf.com/segmentation/table/minnie65_public'

# Set the paths for meshparty and cloudvolume
cv_obj = CloudVolume(seg_source, use_https=True)
mm = trimesh_io.MeshMeta(cv_path=seg_source)

# example cell list
cell_id_list = [864691135397985569] #[864691136175611654] #, 864691135341563589, 864691136100760693, 864691136195001420, 864691135517281235, 864691135505383154] #[864691136143665204] #[864691135135382809, 864691135135829529, 864691136228447569]

example_cell  = cell_id_list[0]

# %%
# %%time
mm_mesh = mm.mesh(seg_id=example_cell, remove_duplicate_vertices=True) #, cache_mesh=False)
# Out:
# ...
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: storage.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: storage.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: storage.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: storage.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: storage.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: storage.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: storage.googleapis.com. Connection pool size: 10
# ...

# %%
# %%time
# cv_mesh = cv_obj.mesh.get(example_cell, remove_duplicate_vertices=True) #, use_https=True)

# %%
# print('meshparty trimesh object: ', mm_mesh)
# print('cloudvolume mesh object (includes extra metadata):', cv_mesh[example_cell])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mesh_dir = '/content/drive/MyDrive/minnie65/meshes/'

# %%
mm = trimesh_io.MeshMeta(cv_path=seg_source,
                         disk_cache_path=mesh_dir,
                         cache_size=20)

# %%
# %%time

# cell_id_list = [864691136175611654, 864691135341563589, 864691136100760693, 864691136195001420, 864691135517281235, 864691135505383154]
# mm_mesh = mm.mesh(seg_id=cell_id_list[i], remove_duplicate_vertices=True)

# %%
# %%time

cell_id_list = [864691134965433631, 864691135100839712, 864691135210965952, 864691135446178450, 864691135479068358, 864691135590803467, 864691135718708273, 864691135876855379, 864691136274045374, 864691136311785021, 864691136389425783, 864691136617703131]

#[864691135105583693] #[864691135105583693] #[864691135341563589, 864691136100760693, 864691136195001420, 864691135517281235, 864691135505383154] #[864691136175611654]

for cell_id in cell_id_list:
    mm_mesh = mm.mesh(seg_id=cell_id, remove_duplicate_vertices=True)
# Out:
# CPU times: user 19.3 s, sys: 4.91 s, total: 24.3 s
# Wall time: 24.4 s
